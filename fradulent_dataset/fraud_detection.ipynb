# %% [markdown]
# ## About Data

# %% [markdown]
# step - maps a unit of time in the real world. In this case 1 step is 1 hour of time. Total steps 744 (30 days simulation).
#
# type - CASH-IN, CASH-OUT, DEBIT, PAYMENT and TRANSFER.
#
# amount - amount of the transaction in local currency.
#
# nameOrig - customer who started the transaction
#
# oldbalanceOrg - initial balance before the transaction
#
# newbalanceOrig - new balance after the transaction
#
# nameDest - customer who is the recipient of the transaction
#
# oldbalanceDest - initial balance recipient before the transaction. Note that there is not information for customers that start with M (Merchants).
#
# newbalanceDest - new balance recipient after the transaction. Note that there is not information for customers that start with M (Merchants).
#
# isFraud - This is the transactions made by the fraudulent agents inside the simulation. In this specific dataset the fraudulent behavior of the agents aims to profit by taking control or customers accounts and try to empty the funds by transferring to another account and then cashing out of the system.
#
# isFlaggedFraud - The business model aims to control massive transfers from one account to another and flags illegal attempts. An illegal attempt in this dataset is an attempt to transfer more than 200.000 in a single transaction.

# %% [markdown]
# ## **IMPORTING LIBRARIES**

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in /home/rohan/anaconda3/lib/python3.12/site-packages (3.0.4)
# Requirement already satisfied: numpy in /home/rohan/anaconda3/lib/python3.12/site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: nvidia-nccl-cu12 in /home/rohan/anaconda3/lib/python3.12/site-packages (from xgboost) (2.27.7)
# Requirement already satisfied: scipy in /home/rohan/anaconda3/lib/python3.12/site-packages (from xgboost) (1.13.1)

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from xgboost import XGBClassifier

# %% [markdown]
# ## **DATA COLLECTION AND READING**

# %%
df=pd.read_csv('Fraud.csv')
df_new=pd.read_csv( 'Fraud.csv',nrows=3000000)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   nameOrig        object
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        object
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 534.0+ MB

# %%
def summary(df):
    sum = pd.DataFrame(df.dtypes, columns=['dtypes'])
    sum['missing#'] = df.isna().sum()
    sum['missing%'] = (df.isna().sum().values*100)/len(df)
    sum['uniques'] = df.nunique().values
    sum['count'] = df.count().values
    desc = pd.DataFrame(df.describe().T)
    sum['min'] = desc['min']
    sum['max'] = desc['max']
    sum['mean'] = desc['mean']
    return sum

summary(df).style.background_gradient(cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_d0be1_row0_col1, #T_d0be1_row0_col2, #T_d0be1_row0_col3, #T_d0be1_row0_col4, #T_d0be1_row0_col6, #T_d0be1_row0_col7, #T_d0be1_row1_col1, #T_d0be1_row1_col2, #T_d0be1_row1_col3, #T_d0be1_row1_col4, #T_d0be1_row2_col1, #T_d0be1_row2_col2, #T_d0be1_row2_col4, #T_d0be1_row2_col5, #T_d0be1_row3_col1, #T_d0be1_row3_col2, #T_d0be1_row3_col4, #T_d0be1_row4_col1, #T_d0be1_row4_col2, #T_d0be1_row4_col4, #T_d0be1_row4_col5, #T_d0be1_row5_col1, #T_d0be1_row5_col2, #T_d0be1_row5_col4, #T_d0be1_row5_col5, #T_d0be1_row6_col1, #T_d0be1_row6_col2, #T_d0be1_row6_col4, #T_d0be1_row7_col1, #T_d0be1_row7_col2, #T_d0be1_row7_col4, #T_d0be1_row7_col5, #T_d0be1_row8_col1, #T_d0be1_row8_col2, #T_d0be1_row8_col4, #T_d0be1_row8_col5, #T_d0be1_row9_col1, #T_d0be1_row9_col2, #T_d0be1_row9_col3, #T_d0be1_row9_col4, #T_d0be1_row9_col5, #T_d0be1_row9_col6, #T_d0be1_row9_col7, #T_d0be1_row10_col1, #T_d0be1_row10_col2, #T_d0be1_row10_col3, #T_d0be1_row10_col4, #T_d0be1_row10_col5, #T_d0be1_row10_col6, #T_d0be1_row10_col7 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# #T_d0be1_row0_col5, #T_d0be1_row3_col3, #T_d0be1_row7_col6, #T_d0be1_row8_col6, #T_d0be1_row8_col7 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_d0be1_row1_col5, #T_d0be1_row1_col6, #T_d0be1_row1_col7, #T_d0be1_row3_col5, #T_d0be1_row3_col6, #T_d0be1_row3_col7, #T_d0be1_row6_col5, #T_d0be1_row6_col6, #T_d0be1_row6_col7 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d0be1_row2_col3 {
#   background-color: #c80723;
#   color: #f1f1f1;
# }
# #T_d0be1_row2_col6 {
#   background-color: #fed673;
#   color: #000000;
# }
# #T_d0be1_row2_col7 {
#   background-color: #ffea99;
#   color: #000000;
# }
# #T_d0be1_row4_col3 {
#   background-color: #fecc68;
#   color: #000000;
# }
# #T_d0be1_row4_col6 {
#   background-color: #ffe793;
#   color: #000000;
# }
# #T_d0be1_row4_col7 {
#   background-color: #f13624;
#   color: #f1f1f1;
# }
# #T_d0be1_row5_col3 {
#   background-color: #fea446;
#   color: #000000;
# }
# #T_d0be1_row5_col6 {
#   background-color: #ffeb9c;
#   color: #000000;
# }
# #T_d0be1_row5_col7 {
#   background-color: #ed3022;
#   color: #f1f1f1;
# }
# #T_d0be1_row6_col3 {
#   background-color: #fea245;
#   color: #000000;
# }
# #T_d0be1_row7_col3 {
#   background-color: #fc6a32;
#   color: #f1f1f1;
# }
# #T_d0be1_row7_col7 {
#   background-color: #b00026;
#   color: #f1f1f1;
# }
# #T_d0be1_row8_col3 {
#   background-color: #fd6e33;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d0be1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d0be1_level0_col0" class="col_heading level0 col0" >dtypes</th>
#       <th id="T_d0be1_level0_col1" class="col_heading level0 col1" >missing#</th>
#       <th id="T_d0be1_level0_col2" class="col_heading level0 col2" >missing%</th>
#       <th id="T_d0be1_level0_col3" class="col_heading level0 col3" >uniques</th>
#       <th id="T_d0be1_level0_col4" class="col_heading level0 col4" >count</th>
#       <th id="T_d0be1_level0_col5" class="col_heading level0 col5" >min</th>
#       <th id="T_d0be1_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_d0be1_level0_col7" class="col_heading level0 col7" >mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0be1_level0_row0" class="row_heading level0 row0" >step</th>
#       <td id="T_d0be1_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_d0be1_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d0be1_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_d0be1_row0_col3" class="data row0 col3" >743</td>
#       <td id="T_d0be1_row0_col4" class="data row0 col4" >6362620</td>
#       <td id="T_d0be1_row0_col5" class="data row0 col5" >1.000000</td>
#       <td id="T_d0be1_row0_col6" class="data row0 col6" >743.000000</td>
#       <td id="T_d0be1_row0_col7" class="data row0 col7" >243.397246</td>
#     </tr>
#     <tr>
#       <th id="T_d0be1_level0_row1" class="row_heading level0 row1" >type</th>
#       <td id="T_d0be1_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_d0be1_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_d0be1_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_d0be1_row1_col3" class="data row1 col3" >5</td>
#       <td id="T_d0be1_row1_col4" class="data row1 col4" >6362620</td>
#       <td id="T_d0be1_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_d0be1_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_d0be1_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0be1_level0_row2" class="row_heading level0 row2" >amount</th>
#       <td id="T_d0be1_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_d0be1_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_d0be1_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_d0be1_row2_col3" class="data row2 col3" >5316900</td>
#       <td id="T_d0be1_row2_col4" class="data row2 col4" >6362620</td>
#       <td id="T_d0be1_row2_col5" class="data row2 col5" >0.000000</td>
#       <td id="T_d0be1_row2_col6" class="data row2 col6" >92445516.640000</td>
#       <td id="T_d0be1_row2_col7" class="data row2 col7" >179861.903549</td>
#     </tr>
#     <tr>
#       <th id="T_d0be1_level0_row3" class="row_heading level0 row3" >nameOrig</th>
#       <td id="T_d0be1_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_d0be1_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_d0be1_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_d0be1_row3_col3" class="data row3 col3" >6353307</td>
#       <td id="T_d0be1_row3_col4" class="data row3 col4" >6362620</td>
#       <td id="T_d0be1_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_d0be1_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_d0be1_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0be1_level0_row4" class="row_heading level0 row4" >oldbalanceOrg</th>
#       <td id="T_d0be1_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_d0be1_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_d0be1_row4_col2" class="data row4 col2" >0.000000</td>
#       <td id="T_d0be1_row4_col3" class="data row4 col3" >1845844</td>
#       <td id="T_d0be1_row4_col4" class="data row4 col4" >6362620</td>
#       <td id="T_d0be1_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_d0be1_row4_col6" class="data row4 col6" >59585040.370000</td>
#       <td id="T_d0be1_row4_col7" class="data row4 col7" >833883.104074</td>
#     </tr>
#     <tr>
#       <th id="T_d0be1_level0_row5" class="row_heading level0 row5" >newbalanceOrig</th>
#       <td id="T_d0be1_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_d0be1_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_d0be1_row5_col2" class="data row5 col2" >0.000000</td>
#       <td id="T_d0be1_row5_col3" class="data row5 col3" >2682586</td>
#       <td id="T_d0be1_row5_col4" class="data row5 col4" >6362620</td>
#       <td id="T_d0be1_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_d0be1_row5_col6" class="data row5 col6" >49585040.370000</td>
#       <td id="T_d0be1_row5_col7" class="data row5 col7" >855113.668579</td>
#     </tr>
#     <tr>
#       <th id="T_d0be1_level0_row6" class="row_heading level0 row6" >nameDest</th>
#       <td id="T_d0be1_row6_col0" class="data row6 col0" >object</td>
#       <td id="T_d0be1_row6_col1" class="data row6 col1" >0</td>
#       <td id="T_d0be1_row6_col2" class="data row6 col2" >0.000000</td>
#       <td id="T_d0be1_row6_col3" class="data row6 col3" >2722362</td>
#       <td id="T_d0be1_row6_col4" class="data row6 col4" >6362620</td>
#       <td id="T_d0be1_row6_col5" class="data row6 col5" >nan</td>
#       <td id="T_d0be1_row6_col6" class="data row6 col6" >nan</td>
#       <td id="T_d0be1_row6_col7" class="data row6 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d0be1_level0_row7" class="row_heading level0 row7" >oldbalanceDest</th>
#       <td id="T_d0be1_row7_col0" class="data row7 col0" >float64</td>
#       <td id="T_d0be1_row7_col1" class="data row7 col1" >0</td>
#       <td id="T_d0be1_row7_col2" class="data

# %% [markdown]
# ## findings
#
# 1. There are 6362620 rows and 11 columns in the dataset.
# 2. There are no null values in the dataset.
# 3. There are 6 types of transactions in the dataset - CASH-IN, CASH-OUT, DEBIT, PAYMENT, TRANSFER and CASH-IN.
# 4. The dataset contains 8213 fraudulent transactions and 6354407 non-fraudulent transactions.
# 5. The dataset contains 0 flagged fraudulent transactions.
# 6. The maximum transaction amount is 25691.16 and the minimum transaction amount is 0.0.

# %%
# NO null values
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
# No Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# we will drop this kind of imbalance feature
df['isFlaggedFraud'].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.boxplot(figsize=(12,6))
# Out:
# <Axes: >

# %%
import pandas as pd

# Select only numeric columns
numeric_columns = df.select_dtypes(include=['int64','float64'])

# Calculate quantiles for numeric columns
Q1 = numeric_columns.quantile(0.25)
Q3 = numeric_columns.quantile(0.75)
IQR = Q3 - Q1

# Function to detect outliers and calculate their percentage
def detect_outliers(column):
    lower_bound = Q1[column] - 1.5 * IQR[column]
    upper_bound = Q3[column] + 1.5 * IQR[column]
    outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
    if outliers.empty:
        return None, 0.0
    else:
        percentage = (len(outliers) / len(df)) * 100
        return column, percentage

columns_with_outliers = [detect_outliers(column) for column in numeric_columns.columns]
columns_with_outliers = [(column, percentage) for column, percentage in columns_with_outliers if column is not None]

for column, percentage in columns_with_outliers:
    print(f"Column: {column}, Percentage of outliers: {percentage:.2f}%")
# Out:
# Column: step, Percentage of outliers: 1.61%
# Column: amount, Percentage of outliers: 5.31%
# Column: oldbalanceOrg, Percentage of outliers: 17.49%
# Column: newbalanceOrig, Percentage of outliers: 16.56%
# Column: oldbalanceDest, Percentage of outliers: 12.36%
# Column: newbalanceDest, Percentage of outliers: 11.61%
# Column: isFraud, Percentage of outliers: 0.13%
# Column: isFlaggedFraud, Percentage of outliers: 0.00%

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64'])

correlation_matrix = numeric_columns.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='YlOrRd')
plt.show()

# %%
# due high Multicollinearity we will drop oldbalance data beacuse instead of that columns we can make use of newbalance data
df.drop(columns=['oldbalanceDest', 'oldbalanceOrg'], inplace=True)

# %%
numeric_columns = df.select_dtypes(include=['int64', 'float64'])

correlation_matrix = numeric_columns.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='YlOrRd')
plt.show()

# %%
# Distribution of Transaction Types
sns.countplot(data=df, x='type')
plt.xlabel('Transaction Type')
plt.ylabel('Count')
plt.title('Distribution of Transaction Types')
# Out:
# Text(0.5, 1.0, 'Distribution of Transaction Types')

# %%
# the highest transaction amount is transfered by TRANSFER type
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x='type', y='amount')
plt.xticks(rotation=0)  
plt.xlabel('Transaction Type')
plt.ylabel('Transaction Amount')
plt.title('Transaction Amount by Type')
plt.show()

# %%
# There are total 744 steps, In this case 1 step is 1 hour of time
# Fraud transaction happend within 1 or 2 steps, means in less time
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='amount', y='step', hue='isFraud', alpha=0.5)
plt.xlabel('Step')
plt.ylabel('Amount')
plt.title('Scatter Plot of Step vs. Amount with Fraudulent Status (Hue)')
plt.grid(True)
plt.tight_layout()
plt.legend(title='Is Fraud')
plt.show()

# %%
# Fraud transaction is happend by two types only 'TRANSFER' and 'CASH_OUT'
fraud_proportion = df[df['isFraud'] == 1]['type'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(fraud_proportion, labels=fraud_proportion.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Fraudulent Transactions by Type')
plt.show()

# %% [markdown]
# ## **USING df_new**

# %% [markdown]
# * here we will use df_new because system was unable to handle whole data
# * From df_new we will drop 'isFlaggedFraud' because it was highly imbalanced
# * we have to drop highly correlated columns i.e 'oldbalanceOrg' and 'oldbalanceDest'.

# %%
df_new.drop(['oldbalanceOrg','oldbalanceDest','isFlaggedFraud'],axis=1,inplace=True)

# %%
# Treating ouliers
df_new.boxplot(figsize=(12,6))
# Out:
# <Axes: >

# %%
numeric_columns = df_new.select_dtypes(include=['int64','float64'])

# Calculate quantiles for numeric columns
Q1 = numeric_columns.quantile(0.25)
Q3 = numeric_columns.quantile(0.75)
IQR = Q3 - Q1

# The rest of your code to detect outliers should remain the same
def detect_outliers(column):
    lower_bound = Q1[column] - 1.5 * IQR[column]
    upper_bound = Q3[column] + 1.5 * IQR[column]
    outliers = df_new[(df_new[column] < lower_bound) | (df_new[column] > upper_bound)]
    if outliers.empty:
        return None, 0.0
    else:
        percentage = (len(outliers) / len(df_new)) * 100
        return column, percentage

columns_with_outliers = [detect_outliers(column) for column in numeric_columns.columns]
columns_with_outliers = [(column, percentage) for column, percentage in columns_with_outliers if column is not None]

for column, percentage in columns_with_outliers:
    print(f"Column: {column}, Percentage of outliers: {percentage:.2f}%")
# Out:
# Column: amount, Percentage of outliers: 5.04%
# Column: newbalanceOrig, Percentage of outliers: 16.40%
# Column: newbalanceDest, Percentage of outliers: 11.06%
# Column: isFraud, Percentage of outliers: 0.09%

# %%
# removing outliers
def remove_outlier(col):
    sorted(col)
    Q1,Q3=col.quantile([0.25,0.75])
    IQR=Q3-Q1
    lower_range=Q1-1.5*IQR
    upper_range=Q3+1.5*IQR
    return lower_range,upper_range

# %%
low_leadtime,high_leadtime=remove_outlier(df_new['newbalanceOrig'])
df_new['newbalanceOrig']=np.where(df_new['newbalanceOrig']>high_leadtime,high_leadtime,df_new['newbalanceOrig'])
df_new['newbalanceOrig']=np.where(df_new['newbalanceOrig']<low_leadtime,low_leadtime,df_new['newbalanceOrig'])

# %%
low_leadtime,high_leadtime=remove_outlier(df_new['newbalanceDest'])
df_new['newbalanceDest']=np.where(df_new['newbalanceDest']>high_leadtime,high_leadtime,df_new['newbalanceDest'])
df_new['newbalanceDest']=np.where(df_new['newbalanceDest']<low_leadtime,low_leadtime,df_new['newbalanceDest'])

# %% [markdown]
# ## **ENCODING**

# %%
# encoding 'type' column
df_new = pd.get_dummies(df_new, columns=['type'], prefix=['type'])
df_new.shape
# Out:
# (3000000, 12)

# %%
df_new.head()
# Out:
#    step    amount     nameOrig  newbalanceOrig     nameDest  newbalanceDest  \
# 0     1   9839.64  C1231006815       160296.36  M1979787155             0.0
# 1     1   1864.28  C1666544295        19384.72  M2044282225             0.0
# 2     1    181.00  C1305486145            0.00   C553264065             0.0
# 3     1    181.00   C840083671            0.00    C38997010             0.0
# 4     1  11668.14  C2048537720        29885.86  M1230701703             0.0
#
#    isFraud  type_CASH_IN  type_CASH_OUT  type_DEBIT  type_PAYMENT  \
# 0        0         False          False       False          True
# 1        0         False          False       False          True
# 2        1         False          False       False         False
# 3        1         False           True       False         False
# 4        0         False          False       False          True
#
#    type_TRANSFER
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False

# %%
# encoding 'nameOrig' and 'nameDest'
le=LabelEncoder()
df_new['nameOrig']=le.fit_transform(df_new['nameOrig'])
df_new['nameDest']=le.fit_transform(df_new['nameDest'])

# %%
df_new.head(5)
# Out:
#    step    amount  nameOrig  newbalanceOrig  nameDest  newbalanceDest  \
# 0     1   9839.64    358086       160296.36    780575             0.0
# 1     1   1864.28   1033293        19384.72    814368             0.0
# 2     1    181.00    473430            0.00    208115             0.0
# 3     1    181.00   2749909            0.00    185468             0.0
# 4     1  11668.14   1625449        29885.86    390711             0.0
#
#    isFraud  type_CASH_IN  type_CASH_OUT  type_DEBIT  type_PAYMENT  \
# 0        0         False          False       False          True
# 1        0         False          False       False          True
# 2        1         False          False       False         False
# 3        1         False           True       False         False
# 4        0         False          False       False          True
#
#    type_TRANSFER
# 0          False
# 1          False
# 2           True
# 3          False
# 4          False

# %%
# Highly imbalanced
df_new['isFraud'].value_counts()
# Out:
# isFraud
# 0    2997381
# 1       2619
# Name: count, dtype: int64

# %% [markdown]
# ## **SPLITTING**|

# %%
x=df_new.drop(['isFraud'],axis=1)
y=df_new['isFraud']

# %% [markdown]
# ### **SMOTING**

# %%
smote = SMOTE(sampling_strategy='auto', random_state=42)
x, y = smote.fit_resample(x, y)

# %%
y.value_counts()
# Out:
# isFraud
# 0    2997381
# 1    2997381
# Name: count, dtype: int64

# %% [markdown]
# ### **TRAIN TEST SPLITTING**

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,random_state=142)

# %%
print(xtrain.shape)
print(xtest.shape)
print(ytrain.shape)
print(ytest.shape)
# Out:
# (4496071, 11)
# (1498691, 11)
# (4496071,)
# (1498691,)

# %%
#scaling the data
sc=StandardScaler()
xtrain_sc = sc.fit_transform(xtrain)
xtest_sc=sc.transform(xtest)

# %%
# accuracy funtion
def acc_report(actual,predicted):
    acc_score=accuracy_score(actual,predicted)
    class_rep=classification_report(actual,predicted)
    print('the accuracy of tha model is ',acc_score)
    print(class_rep)

# %% [markdown]
# ## **LogisticRegression**

# %%
# Initialize and train the Logistic Regression model
lgr = LogisticRegression(max_iter=500)
lgr.fit(xtrain_sc, ytrain)
# Out:
# LogisticRegression(max_iter=500)

# %%
ypred_train_lgr=lgr.predict(xtrain_sc)
ypred_test_lgr=lgr.predict(xtest_sc)

# %%
acc_report(ytrain,ypred_train_lgr)
acc_report(ytest,ypred_test_lgr)
# Out:
# the accuracy of tha model is  0.8426826444689152
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83   2247761
#            1       0.80      0.92      0.85   2248310
#
#     accuracy                           0.84   4496071
#    macro avg       0.85      0.84      0.84   4496071
# weighted avg       0.85      0.84      0.84   4496071
#
# the accuracy of tha model is  0.8426500192501323
#               precision    recall  f1-score   support
#
#            0       0.90      0.77      0.83    749620
#            1       0.80      0.92      0.85    749071
#
#     accuracy                           0.84   1498691
#    macro avg       0.85      0.84      0.84   1498691
# weighted avg       0.85      0.84      0.84   1498691

# %%
rand_model=RandomForestClassifier()
rand_model.fit(xtrain_sc,ytrain)
# Out:
# RandomForestClassifier()

# %%
ypred_train_rand=rand_model.predict(xtrain_sc)
ypred_test_rand=rand_model.predict(xtest_sc)

# %%
acc_report(ytrain,ypred_train_rand)
acc_report(ytest,ypred_test_rand)
# Out:
# the accuracy of tha model is  1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00   2247761
#            1       1.00      1.00      1.00   2248310
#
#     accuracy                           1.00   4496071
#    macro avg       1.00      1.00      1.00   4496071
# weighted avg       1.00      1.00      1.00   4496071
#
# the accuracy of tha model is  0.9991225676273494
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    749620
#            1       1.00      1.00      1.00    749071
#
#     accuracy                           1.00   1498691
#    macro avg       1.00      1.00      1.00   1498691
# weighted avg       1.00      1.00      1.00   1498691

# %% [markdown]
# ## **Identifying important features**

# %%
# coefficients indicate the strength and direction of the relationship between each feature and the target variable
feature_coefficients = lgr.coef_[0]

feature_importance_df = pd.DataFrame({
    'Feature': xtrain.columns,
    'Coefficient': feature_coefficients
})

feature_importance_df['Absolute_Coefficient'] = feature_importance_df['Coefficient'].abs()
feature_importance_df = feature_importance_df.sort_values(by='Absolute_Coefficient', ascending=False)

print(feature_importance_df)
# Out:
#            Feature  Coefficient  Absolute_Coefficient
# 7    type_CASH_OUT     7.174176              7.174176
# 10   type_TRANSFER     6.966925              6.966925
# 3   newbalanceOrig    -4.688415              4.688415
# 1           amount     3.383848              3.383848
# 9     type_PAYMENT    -2.859389              2.859389
# 5   newbalanceDest    -0.931039              0.931039
# 4         nameDest     0.235792              0.235792
# 8       type_DEBIT    -0.228178              0.228178
# 0             step    -0.184564              0.184564
# 6     type_CASH_IN    -0.142692              0.142692
# 2         nameOrig     0.009554              0.009554

# %%
## identifying from random forest
importances = rand_model.feature_importances_
feature_importance_df_rf = pd.DataFrame({
    'Feature': xtrain.columns,
    'Importance': importances
})
feature_importance_df_rf = feature_importance_df_rf.sort_values(by='Importance', ascending=False)
print(feature_importance_df_rf)
# Plotting feature importance from Random Forest
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df_rf)
plt.title('Feature Importance from Random Forest')
plt.show()
# Out:
#            Feature  Importance
# 5   newbalanceDest    0.167938
# 1           amount    0.158502
# 0             step    0.137892
# 10   type_TRANSFER    0.126049
# 3   newbalanceOrig    0.124137
# 4         nameDest    0.108761
# 2         nameOrig    0.055510
# 7    type_CASH_OUT    0.053850
# 9     type_PAYMENT    0.042101
# 6     type_CASH_IN    0.024755
# 8       type_DEBIT    0.000505

# %% [markdown]
# ## Both the models have their own pros and cons for example:

# %% [markdown]
# > Logistic regression take less time to train the model but it is not as accurate as RandomForestClassifier.
# > RandomForestClassifier takes more time to train the model but it is more accurate than Logistic regression.
